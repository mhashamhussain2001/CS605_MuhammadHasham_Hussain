# %% [markdown]
# <a href="https://colab.research.google.com/github/mhashamhussain2001/CS605_MuhammadHasham_Hussain/blob/main/Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CSCI 608 Final Project
#
# ## 1. Problem Formulation
# Looking at our music and mental health dataset from Kaggle, we see that we can form multiple types of questions, and perform different operations and analysis using our variables.
#
# ### Descriptive Question:
# *What does the distribution of respondents' anxiety score, and daily music listening hours look like?*
#
# ### Exploratory Question
# *Is there an association between daily muisc listening hours and self reported anxiety scores?*
#
# ### Predictive Question
# *Can we predict anxiety scores for a person, given their daily music listening hours, favourite genres, *
#
# ### Inferential Question
# *r*

# %%
import pandas as pd
import numpy as np

# %%
url = "https://raw.githubusercontent.com/mhashamhussain2001/CSCI608_FinalProject/refs/heads/main/mxmh_survey_results.csv"
df = pd.read_csv(url)
df
# Out:
#                Timestamp   Age Primary streaming service  Hours per day  \
# 0     8/27/2022 19:29:02  18.0                   Spotify            3.0
# 1     8/27/2022 19:57:31  63.0                   Pandora            1.5
# 2     8/27/2022 21:28:18  18.0                   Spotify            4.0
# 3     8/27/2022 21:40:40  61.0             YouTube Music            2.5
# 4     8/27/2022 21:54:47  18.0                   Spotify            4.0
# ..                   ...   ...                       ...            ...
# 731  10/30/2022 14:37:28  17.0                   Spotify            2.0
# 732   11/1/2022 22:26:42  18.0                   Spotify            1.0
# 733   11/3/2022 23:24:38  19.0   Other streaming service            6.0
# 734   11/4/2022 17:31:47  19.0                   Spotify            5.0
# 735    11/9/2022 1:55:20  29.0             YouTube Music            2.0
#
#     While working Instrumentalist Composer         Fav genre Exploratory  \
# ...
